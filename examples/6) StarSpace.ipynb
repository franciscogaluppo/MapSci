# %% [markdown]
# # StarSpace
#
# Each topic is thus identified by a vector $vec^t_j$ defined by the $N$-dimensional embedding for topic j, learned with the StarSpace model by observing scientists publication patterns in time window $t$. In this model, entity embeddings are learned using discrete feature representations describing the relations between the selected entities.

# %%
import sys
sys.path.append("../")
from lib.rs import research_space

# %%
key = "sjr"
rs = research_space(key)
rs.load(2011)

# %%
import pandas as pd
areas = pd.read_pickle("../../dataset/SJR/areas.pkl")
areas.head()
# Out:
#      Code                                              Field     Subject area  \
# 0  1000.0                                  multidisciplinary  health sciences
# 1  1100.0       general agricultural and biological sciences    life sciences
# 2  1101.0  agricultural and biological sciences (miscella...    life sciences
# 3  1102.0                          agronomy and crop science    life sciences
# 4  1103.0                         animal science and zoology    life sciences
#
#                          Classification
# 0                     multidisciplinary
# 1  agricultural and biological sciences
# 2  agricultural and biological sciences
# 3  agricultural and biological sciences
# 4  agricultural and biological sciences

# %%
dict_area = areas[["Field", "Subject area"]].set_index("Field").to_dict()["Subject area"]
unique = areas["Subject area"].unique()
subs = {u: v for v,u in enumerate(sorted(unique))}
values = [subs[dict_area[node]] for node in rs.fields]

pos = rs.plot(values, labels=subs, new=True)

# %%
rs.load_star_space(200)

# %%
dict_area = areas[["Field", "Subject area"]].set_index("Field").to_dict()["Subject area"]
unique = areas["Subject area"].unique()
subs = {u: v for v,u in enumerate(sorted(unique))}
values = [subs[dict_area[node]] for node in rs.fields]

rs.plot(values, labels=subs, threshold=0.3, new=True)
